# %%
str1='dkte'
str2="dkte"
str3='10'
print(type(str2))
print(type(str3))
print(type(str1))
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>

# %%
str1='dkte'
str2='college'
print(str1+str2)
# Out:
# dktecollege

# %%
str1='dkte'
str2='college'
print(str1+' '+str2)
# Out:
# dkte college

# %%
str1='dkte'
print(len(str1))
str2='dkte college'
print(len(str2))
# Out:
# 4
# 12

# %%
str1="Hello"
print(str1[4])
print(str1[0])
print(str1[6])
str2="Namaste"
print(str2[5])
print(str2[0])
print(str2[6])
print(str2[8])
# Out:
# o
# H
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2980\3817112081.py in <module>
#       2 print(str1[4])
#       3 print(str1[0])
# ----> 4 print(str1[6])
#       5 str2="Namaste"
#       6 print(str2[5])
#
# IndexError: string index out of range

# %%
str1='dkte'
print(str1[1:3])
print(str1[ :2])
print(str1[1: ])
print(str1[ : ])
# Out:
# kt
# dk
# kte
# dkte

# %%
str1='dkte'
print(str1[-1:-4])

# %%
str1="Krisha Shaha"
print(len(str1))
# Out:
# 12

# %%
str1="Krisha Champalal Shaha"
print(str1[7:17])
# Out:
# Champalal

# %%
str(input("enter a name"))
print(str1[:])
# Out:
# enter a name krisha champalal shaha
# Krisha Champalal Shaha

# %%
str1='Dkte'
print(str1.startswith("D"))
print(str1.endswith("e"))
# Out:
# True
# True

# %%
str1="Dkte College"
print(str1.istitle())
str2="dkte college"
print(str2.istitle())
# Out:
# True
# False

# %%
str1="DKTE"
print(str1.isupper())
str2="dkte"
print(str2.isupper())
# Out:
# True
# False

# %%
str1="dkte"
print(str1.islower())
str2="DKTE"
print(str2.islower())
# Out:
# True
# False

# %%
str1="krisha"
print(str1.isalpha())
str2="123"
print(str2.isalpha())
# Out:
# True
# False

# %%
str1="1342"
print(str1.isdecimal())
str2="hello"
print(str2.isdecimal())
# Out:
# True
# False

# %%
str1="Ichalkaranji"
print(str1.find('a'))
# Out:
# 3

# %%
str1="Ichalkaranji"
print(str1.replace('a','k'))
# Out:
# Ichklkkrknji
