# %%
fruits=["apple","mango","banana"]
print(fruits)
# Out:
# ['apple', 'mango', 'banana']

# %%
print(fruits[1])
# Out:
# mango

# %%
print(fruits[1:3])
# Out:
# ['mango', 'banana']

# %%
print(len(fruits))
# Out:
# 3

# %%
fruits[1]="orange"
print(fruits)
# Out:
# ['apple', 'orange', 'banana']

# %%
fruits=["apple","mango","banana"]
fruits.append("papaya")
print(fruits)
# Out:
# ['apple', 'mango', 'banana', 'papaya']

# %%
print(type(fruits))
# Out:
# <class 'list'>

# %%
fruits=["apple","mango","banana"]
fruits.remove("mango")
print(fruits)
# Out:
# ['apple', 'banana']

# %%
fruits=["apple","mango","banana"]
fruits.sort()
print(fruits)
# Out:
# ['apple', 'banana', 'mango']

# %%
fruits=["apple","mango","banana"]
fruits.sort(reverse=True)
print(fruits)
# Out:
# ['mango', 'banana', 'apple']

# %%
fruits=["apple","mango","banana"]
fruits1=["cherry","guava"]
fruits.extend(fruits1)
print(fruits)
# Out:
# ['apple', 'mango', 'banana', 'cherry', 'guava']

# %%
fruits=["apple","mango","banana"]
fruits.extend(["cherry","guava"])
print(fruits)
# Out:
# ['apple', 'mango', 'banana', 'cherry', 'guava']

# %%
fruits=["apple","mango","banana"]
fruits.insert(1,"cherry")
print(fruits)
# Out:
# ['apple', 'cherry', 'mango', 'banana']

# %%
tup1=(10,20,30,15,20)
print(len(tup1))
# Out:
# 5

# %%
num=(1,)
print(type(num))
# Out:
# <class 'tuple'>

# %%
 tup1=(10,20,30,15,20)
print(tup1.index(20))
# Out:
# 1

# %%
 tup1=(10,20,30,15,20)
print(tup1.count(20))
# Out:
# 2

# %%
 tup1=(10,20,30,15,20)
print(max(tup1))
# Out:
# 30

# %%
 tup1=(10,20,30,15,20)
print(min(tup1))
# Out:
# 10

# %%
 tup1=(10,20,30,15,20)
print(sorted(tup1))
# Out:
# [10, 15, 20, 20, 30]
